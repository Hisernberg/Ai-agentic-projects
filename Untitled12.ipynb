# %% [markdown]
# <a href="https://colab.research.google.com/github/Hisernberg/Ai-agentic-projects/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface
from deepface import DeepFace
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 47.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.6 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=5da0990880a53d19c8765f66f0c3bf6d0f174a58350b26c1ee5724b54ed0ce8d
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...
# 25-06-05 13:32:00 - Directory /root/.deepface has been created
# 25-06-05 13:32:00 - Directory /root/.deepface/weights has been created

# %%
from google.colab import files

# Upload an image (JPG, PNG, etc.)
uploaded = files.upload()

# Get the path of uploaded image
img_path = list(uploaded.keys())[0]
print("✅ Image uploaded:", img_path)
# Out:
#      <input type="file" id="files-10b3ebed-e706-4d45-8943-631f671c6344" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10b3ebed-e706-4d45-8943-631f671c6344">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
result = DeepFace.analyze(img_path=img_path, actions=['emotion'])

# Extract dominant emotion
emotion = result[0]['dominant_emotion']
print("🎭 Detected Emotion:", emotion)
# Out:
# 25-06-05 13:32:55 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 114MB/s]
# 🎭 Detected Emotion: happy

# %%
import matplotlib.pyplot as plt
import cv2
import os

# Check if image exists
if os.path.exists(img_path):
    img = cv2.imread(img_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Plot image with emotion
    plt.figure(figsize=(6,6))
    plt.imshow(img_rgb)
    plt.title(f"🎭 Detected Emotion: {emotion}", fontsize=16)
    plt.axis('off')
    plt.show()
else:
    print("❌ Image not found!")
